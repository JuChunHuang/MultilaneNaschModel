# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
routes = df.groupby("Route_ID")
route5 = routes.get_group(5).reset_index()
route90 = routes.get_group(90).reset_index()
route405 = routes.get_group(405).reset_index()
route520 = routes.get_group(520).reset_index()
df
# Out:
#      Route_ID  startMilepost  endMilepost  \
# 0           5         100.93       101.87
# 1           5         101.87       103.17
# 2           5         103.17       103.42
# 3           5         103.42       104.81
# 4           5         104.81       105.63
# ..        ...            ...          ...
# 219       520           9.60         9.72
# 220       520           9.72        11.35
# 221       520          11.35        12.05
# 222       520          12.05        12.38
# 223       520          12.38        12.83
#
#      Average_daily_traffic_counts_Year_2015 RteType  \
# 0                                     65000      IS
# 1                                     85000      IS
# 2                                    108000      IS
# 3                                    101000      IS
# 4                                    144000      IS
# ..                                      ...     ...
# 219                                   95000      SR
# ...

# %%
sdv100 = np.array([847, 1696, 2553, 3404, 4214])
sdv50 = np.array([795, 1608, 2406, 3173, 4017])
sdv0 = np.array([719, 1408, 2094, 2779, 3470])

# %%
sdv100DECR_5 = []
sdv100INCR_5 = []
sdv50DECR_5 = []
sdv50INCR_5 = []
sdv0DECR_5 = []
sdv0INCR_5 = []
for i in range(route5.shape[0]):
    sdv100DECR_5.append(sdv100[route5["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv100INCR_5.append(sdv100[route5["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv50DECR_5.append(sdv50[route5["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv50INCR_5.append(sdv50[route5["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv0DECR_5.append(sdv0[route5["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv0INCR_5.append(sdv0[route5["Number_of_Lanes_INCR_MP_direction"][i]-1])

# %%
plt.figure(figsize=(10,5))
w = route5["startMilepost"]
y = route5["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100DECR_5, drawstyle="steps-pre")
plt.plot(w, sdv50DECR_5, drawstyle="steps-pre")
plt.plot(w, sdv0DECR_5, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with Interstate 5")
plt.xlabel("Milepost (DECR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
plt.figure(figsize=(10,5))
w = route5["startMilepost"]
y = route5["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100INCR_5, drawstyle="steps-pre")
plt.plot(w, sdv50INCR_5, drawstyle="steps-pre")
plt.plot(w, sdv0INCR_5, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with Interstate 5")
plt.xlabel("Milepost (INCR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
sdv100DECR_90 = []
sdv100INCR_90 = []
sdv50DECR_90 = []
sdv50INCR_90 = []
sdv0DECR_90 = []
sdv0INCR_90 = []
for i in range(route90.shape[0]):
    sdv100DECR_90.append(sdv100[route90["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv100INCR_90.append(sdv100[route90["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv50DECR_90.append(sdv50[route90["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv50INCR_90.append(sdv50[route90["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv0DECR_90.append(sdv0[route90["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv0INCR_90.append(sdv0[route90["Number_of_Lanes_INCR_MP_direction"][i]-1])

# %%
plt.figure(figsize=(10,5))
w = route90["startMilepost"]
y = route90["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100DECR_90, drawstyle="steps-pre")
plt.plot(w, sdv50DECR_90, drawstyle="steps-pre")
plt.plot(w, sdv0DECR_90, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with Interstate 90")
plt.xlabel("Milepost (DECR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
plt.figure(figsize=(10,5))
w = route90["startMilepost"]
y = route90["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100INCR_90, drawstyle="steps-pre")
plt.plot(w, sdv50INCR_90, drawstyle="steps-pre")
plt.plot(w, sdv0INCR_90, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with Interstate 90")
plt.xlabel("Milepost (INCR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
sdv100DECR_405 = []
sdv100INCR_405 = []
sdv50DECR_405 = []
sdv50INCR_405 = []
sdv0DECR_405 = []
sdv0INCR_405 = []
for i in range(route405.shape[0]):
    sdv100DECR_405.append(sdv100[route405["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv100INCR_405.append(sdv100[route405["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv50DECR_405.append(sdv50[route405["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv50INCR_405.append(sdv50[route405["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv0DECR_405.append(sdv0[route405["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv0INCR_405.append(sdv0[route405["Number_of_Lanes_INCR_MP_direction"][i]-1])

# %%
plt.figure(figsize=(10,5))
w = route405["startMilepost"]
y = route405["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100DECR_405, drawstyle="steps-pre")
plt.plot(w, sdv50DECR_405, drawstyle="steps-pre")
plt.plot(w, sdv0DECR_405, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with Interstate 405")
plt.xlabel("Milepost (DECR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
plt.figure(figsize=(10,5))
w = route405["startMilepost"]
y = route405["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100INCR_405, drawstyle="steps-pre")
plt.plot(w, sdv50INCR_405, drawstyle="steps-pre")
plt.plot(w, sdv0INCR_405, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with Interstate 405")
plt.xlabel("Milepost (INCR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
sdv100DECR_520 = []
sdv100INCR_520 = []
sdv50DECR_520 = []
sdv50INCR_520 = []
sdv0DECR_520 = []
sdv0INCR_520 = []
for i in range(route520.shape[0]):
    sdv100DECR_520.append(sdv100[route520["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv100INCR_520.append(sdv100[route520["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv50DECR_520.append(sdv50[route520["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv50INCR_520.append(sdv50[route520["Number_of_Lanes_INCR_MP_direction"][i]-1])
    sdv0DECR_520.append(sdv0[route520["Number_of_Lanes_DECR_MP_direction"][i]-1])
    sdv0INCR_520.append(sdv0[route520["Number_of_Lanes_INCR_MP_direction"][i]-1])

# %%
plt.figure(figsize=(10,5))
w = route520["startMilepost"]
y = route520["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100DECR_520, drawstyle="steps-pre")
plt.plot(w, sdv50DECR_520, drawstyle="steps-pre")
plt.plot(w, sdv0DECR_520, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with State Route 520")
plt.xlabel("Milepost (DECR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')

# %%
plt.figure(figsize=(10,5))
w = route520["startMilepost"]
y = route520["Average_daily_traffic_counts_Year_2015"]/24/2
plt.plot(w, y, drawstyle="steps-pre")
plt.plot(w, sdv100INCR_520, drawstyle="steps-pre")
plt.plot(w, sdv50INCR_520, drawstyle="steps-pre")
plt.plot(w, sdv0INCR_520, drawstyle="steps-pre")
plt.legend(["real situation", r'$P_{SDV}$ = 100%', r'$P_{SDV}$ = 50%', r'$P_{SDV}$ = 0%'])
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.3)
plt.title("Comparison of Traffic Flow with State Route 520")
plt.xlabel("Milepost (INCR)")
plt.ylabel("Total Traffic Flow (vehicles/hour)")
# Out:
# Text(0, 0.5, 'Total Traffic Flow (vehicles/hour)')
